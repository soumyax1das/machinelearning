# %%
"""
This code works on the data downloaded from Kaggle.
Link - https://www.kaggle.com/datasets/heeraldedhia/groceries-dataset
Da
Objective::

"""
